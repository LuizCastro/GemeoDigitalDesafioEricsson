# %% [markdown]
# # 🔥 Real-Time Smoke & Fire Detection using YOLOv12
#
#
# ## 📌 Project Overview: AI That Detects Danger Before It Spreads
#
# This project showcases a cutting-edge **real-time Smoke & Fire Detection System** built using **YOLOv12**, one of the fastest and most accurate object detection models in deep learning.
#
# The goal is simple yet impactful — **use Artificial Intelligence to detect early signs of fire or smoke** in real-time video streams to prevent disasters and save lives.
# From **industrial safety** to **smart surveillance** and **public safety monitoring**, this project demonstrates how AI can transform reactive emergency systems into **proactive safety solutions**.
#
# **🔍 Key Question:** Can AI detect smoke and fire faster than humans — and help stop disasters before they grow?
#
# ---
#
# ## 🧠 Deep Learning Approach
#
# We leverage the **YOLOv12 architecture**, which balances **speed, accuracy, and computational efficiency**. The model processes live video frames or pre-recorded footage, detecting regions with smoke or flames and labeling them with bounding boxes and confidence scores.
#
# *   **Model:** YOLOv12 (You Only Look Once, Version 12)
# *   **Framework:** PyTorch
# *   **Input:** Real-time camera feed or video file
# *   **Output:** Bounding boxes with labels (Smoke \ Fire) and detection confidence
# *   **Deployment Ready:** Easily integrable with IoT alert systems or fire response automation
#
# ---
#
# ## 📊 Data & Training
#
# - **Dataset:** Fire & Smoke image dataset (mixed indoor\outdoor environments)
# - **Preprocessing:** Image resizing, normalization, and augmentation for generalization
# - **Training Framework:** PyTorch + OpenCV
# - **Inference Speed:** ~60 FPS on GPU
# - **Evaluation Metrics:** Precision, Recall, and mAP
#
# ---
#
# ## 🛠️ Tech Stack & Tools
#
# | Category | Tools & Frameworks |
# |-----------|--------------------|
# | Programming | Python 🐍 |
# | Deep Learning | YOLOv12, PyTorch |
# | Computer Vision | OpenCV |
# | Data Handling | NumPy, Matplotlib |
# | Environment | Jupyter Notebook |
#
# ---
#
# ## 📈 Results & Impact
#
# After fine-tuning YOLOv12, the system can:
#
# ✅ **Detect smoke and flames in real time** with high confidence
# ✅ **Operate effectively in different lighting conditions**
# ✅ **Support live video and CCTV camera streams**
# ✅ **Enable faster emergency responses** in industrial and public areas
#
# The results demonstrate the power of **AI-driven early warning systems**, turning raw visual data into **life-saving insights**.
#
# ---
#
# ## 🚀 Why This Project Stands Out
#
# 1. **Practical Impact:** Directly supports fire prevention and emergency systems
# 2. **Real-Time Detection:** Processes video feeds instantly
# 3. **Modern Architecture:** Built with the latest YOLOv12 model
# 4. **IoT Integration Ready:** Can trigger automated alerts
# 5. **Open Source:** Clean, reproducible code for researchers and developers
#
# ---
#
# ## 📂 Project Structure
#
# - `Smoke-Fire-Detection-YOLO-V12.ipynb` — Main notebook
# - `test_videos\` — Input videos for detection
# - `runs\detect\` — Output videos with detections
# - `models\` — Pretrained weights
# - `README.md` — Documentation & setup instructions
#
# ---
#
# ## 👨‍💻 Author
#
# **Mina Nabil Samir** | AI & Data Science Engineer
#
# 🔗 [GitHub Repository](https:\\github.com\the0king0mina\Smoke-Fire-Detection-YOLO-V12)
#
#
# ---
#
# ### 🚨 Let’s Make AI Work for Safety!
#
# *   💡 Found this project useful? **Upvote this notebook!**
# *   💬 Have ideas or feedback? Let’s discuss below!
# *   🧠 Fork this project and test it on your own videos — contribute to making AI safer for everyone.
#
# ---

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("sayedgamal99/smoke-fire-detection-yolo")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'smoke-fire-detection-yolo' dataset.
# Path to dataset files: /kaggle/input/smoke-fire-detection-yolo

# %%
import csv
import shutil
import os
import cv2
import numpy as np

# %%
import os

directory_to_check = "/kaggle/input/smoke-fire-detection-yolo"

print(f"Verificando subpastas em: {directory_to_check}")

def list_all_subfolders(path):
    all_subfolders = []
    for root, dirs, files in os.walk(path):
        for d in dirs:
            all_subfolders.append(os.path.join(root, d))
    return all_subfolders

if os.path.exists(directory_to_check) and os.path.isdir(directory_to_check):
    all_subfolders = list_all_subfolders(directory_to_check)
    if all_subfolders:
        print("Todas as subpastas encontradas:")
        for folder_path in all_subfolders:
            print(f"- {folder_path}")
    else:
        print("Nenhuma subpasta encontrada neste diretório e seus subdiretórios.")
else:
    print(f"O diretório '{directory_to_check}' não existe ou não é um diretório válido.")
# Out:
# Verificando subpastas em: /kaggle/input/smoke-fire-detection-yolo
# Todas as subpastas encontradas:
# - /kaggle/input/smoke-fire-detection-yolo/data
# - /kaggle/input/smoke-fire-detection-yolo/data/val
# - /kaggle/input/smoke-fire-detection-yolo/data/test
# - /kaggle/input/smoke-fire-detection-yolo/data/train
# - /kaggle/input/smoke-fire-detection-yolo/data/val/labels
# - /kaggle/input/smoke-fire-detection-yolo/data/val/images
# - /kaggle/input/smoke-fire-detection-yolo/data/test/labels
# - /kaggle/input/smoke-fire-detection-yolo/data/test/images
# - /kaggle/input/smoke-fire-detection-yolo/data/train/labels
# - /kaggle/input/smoke-fire-detection-yolo/data/train/images

# %%
ROOT = "/kaggle/input/smoke-fire-detection-yolo/data"
BAD_IMAGES_DIR = "/kaggle/working/bad_images"
BAD_LABELS_DIR = "/kaggle/working/bad_labels"
CLEAN_ROOT = "/kaggle/working/clean_data"
REPORT_CSV = "/kaggle/working/data_clean_report.csv"

# %%
bad_list = [
    "/kaggle/input/smoke-fire-detection-yolo/data/train/images/PublicDataset01005.jpg",
    "/kaggle/input/smoke-fire-detection-yolo/data/train/images/PublicDataset00864.jpg",
    "/kaggle/input/smoke-fire-detection-yolo/data/train/images/WEB04185.jpg",
    "/kaggle/input/smoke-fire-detection-yolo/data/train/images/WEB02767.jpg",
    "/kaggle/input/smoke-fire-detection-yolo/data/train/images/PublicDataset01036.jpg",
    "/kaggle/input/smoke-fire-detection-yolo/data/train/images/PublicDataset00934.jpg",
    "/kaggle/input/smoke-fire-detection-yolo/data/train/images/WEB06024.jpg",
    "/kaggle/input/smoke-fire-detection-yolo/data/train/images/WEB02729.jpg",
    "/kaggle/input/smoke-fire-detection-yolo/data/train/images/WEB06022.jpg",
    "/kaggle/input/smoke-fire-detection-yolo/data/train/images/WEB06334.jpg",
    "/kaggle/input/smoke-fire-detection-yolo/data/train/images/WEB04554.jpg",
    "/kaggle/input/smoke-fire-detection-yolo/data/train/images/WEB06336.jpg",
    "/kaggle/input/smoke-fire-detection-yolo/data/train/images/WEB03587.jpg",
    "/kaggle/input/smoke-fire-detection-yolo/data/train/images/WEB06082.jpg",
    "/kaggle/input/smoke-fire-detection-yolo/data/train/images/PublicDataset00900.jpg",
    "/kaggle/input/smoke-fire-detection-yolo/data/val/images/WEB02650.jpg",
    "/kaggle/input/smoke-fire-detection-yolo/data/val/images/WEB02614.jpg",
    "/kaggle/input/smoke-fire-detection-yolo/data/val/images/PublicDataset01007.jpg",
    "/kaggle/input/smoke-fire-detection-yolo/data/test/images/WEB10194.jpg",
    "/kaggle/input/smoke-fire-detection-yolo/data/test/images/WEB10116.jpg",
    "/kaggle/input/smoke-fire-detection-yolo/data/test/images/WEB10972.jpg",
    "/kaggle/input/smoke-fire-detection-yolo/data/test/images/WEB10874.jpg",
]

# %%
os.makedirs(BAD_IMAGES_DIR, exist_ok=True)
os.makedirs(BAD_LABELS_DIR, exist_ok=True)
for split in ["train", "val", "test"]:
    os.makedirs(os.path.join(CLEAN_ROOT, split, "images"), exist_ok=True)
    os.makedirs(os.path.join(CLEAN_ROOT, split, "labels"), exist_ok=True)

def is_valid_image(image_path):
    try:
        img = cv2.imread(image_path)
        if img is None:
            return False
        if img.size == 0:
            return False
        return True
    except Exception as e:
        print(f" Error in Image Read {image_path}: {e}")
        return False

report_rows = []

for split in ["train", "val", "test"]:
    src_img_dir = os.path.join(ROOT, split, "images")
    src_lbl_dir = os.path.join(ROOT, split, "labels")
    dst_img_dir = os.path.join(CLEAN_ROOT, split, "images")
    dst_lbl_dir = os.path.join(CLEAN_ROOT, split, "labels")

    if not os.path.isdir(src_img_dir):
        print("Missing dir:", src_img_dir)
        continue

    for fname in sorted(os.listdir(src_img_dir)):
        src_img = os.path.join(src_img_dir, fname)

        if not os.path.isfile(src_img):
            continue

        if src_img in bad_list:
            shutil.copy2(src_img, BAD_IMAGES_DIR)
            name, _ = os.path.splitext(fname)
            src_label = os.path.join(src_lbl_dir, name + ".txt")
            if os.path.exists(src_label):
                shutil.copy2(src_label, BAD_LABELS_DIR)
                report_rows.append([split, fname, "bad_image_and_label_copied"])
            else:
                report_rows.append([split, fname, "bad_image_copied_label_missing"])
            continue

        if not is_valid_image(src_img):
            print(f"Invalid images : {src_img}")
            shutil.copy2(src_img, BAD_IMAGES_DIR)
            name, _ = os.path.splitext(fname)
            src_label = os.path.join(src_lbl_dir, name + ".txt")
            if os.path.exists(src_label):
                shutil.copy2(src_label, BAD_LABELS_DIR)
                report_rows.append([split, fname, "corrupted_image_and_label_copied"])
            else:
                report_rows.append([split, fname, "corrupted_image_copied_label_missing"])
            continue

        shutil.copy2(src_img, dst_img_dir)
        name, _ = os.path.splitext(fname)
        src_label = os.path.join(src_lbl_dir, name + ".txt")
        if os.path.exists(src_label):
            shutil.copy2(src_label, dst_lbl_dir)
            report_rows.append([split, fname, "copied_with_label"])
        else:
            report_rows.append([split, fname, "copied_label_missing"])

print("=" * 50)
for split in ["train", "val", "test"]:
    clean_dir = os.path.join(CLEAN_ROOT, split, "images")
    if os.path.exists(clean_dir):
        count = len(os.listdir(clean_dir))
        print(f"{split}: {count} Valid Images ")
# Out:
# ...
# train: 14107 Valid Images
# val: 3096 Valid Images
# test: 4302 Valid Images

# %%
print("=" * 50)
print(f"   Invlaid Images Save Her {BAD_IMAGES_DIR}")
print(f" Invlaid Labels Save Her: {BAD_LABELS_DIR}")

with open(REPORT_CSV, "w", newline="", encoding="utf-8") as f:
    w = csv.writer(f)
    w.writerow(["split", "filename", "action"])
    w.writerows(report_rows)
# Out:
# ...
#    Invlaid Images Save Her /kaggle/working/bad_images
#  Invlaid Labels Save Her: /kaggle/working/bad_labels

# %%
yaml_text = f"""train: {CLEAN_ROOT}/train/images
val: {CLEAN_ROOT}/val/images
test: {CLEAN_ROOT}/test/images

nc: 2
names: ['smoke','fire']
"""
with open("/kaggle/working/data.yaml", "w", encoding="utf-8") as yf:
    yf.write(yaml_text)

print("dat.yaml is Done Created")
# Out:
# dat.yaml is Done Created

# %%
import os
import random
import matplotlib.pyplot as plt
import cv2
from pathlib import Path

train_img_path = "/kaggle/input/smoke-fire-detection-yolo/data/train/images"
train_label_path = "/kaggle/input/smoke-fire-detection-yolo/data/train/labels"

sample_imgs = random.sample(os.listdir(train_img_path), 9)

def plot_image_with_boxes(img_path, label_path):
    img = cv2.imread(img_path)
    h, w, _ = img.shape
    label_file = label_path.replace('.jpg', '.txt').replace('.png', '.txt')
    if os.path.exists(label_file):
        with open(label_file, "r") as f:
            for line in f.readlines():
                cls, x_center, y_center, bw, bh = map(float, line.strip().split())
                x1 = int((x_center - bw/2) * w)
                y1 = int((y_center - bh/2) * h)
                x2 = int((x_center + bw/2) * w)
                y2 = int((y_center + bh/2) * h)
                color = (0, 255, 0) if cls == 0 else (0, 0, 255)
                cv2.rectangle(img, (x1, y1), (x2, y2), color, 2)
                cls_name = "smoke" if cls == 0 else "fire"
                cv2.putText(img, cls_name, (x1, y1 - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.7, color, 2)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    return img

plt.figure(figsize=(18, 12))
for i, img_name in enumerate(sample_imgs):
    img_path = os.path.join(train_img_path, img_name)
    label_path = os.path.join(train_label_path, img_name)
    plt.subplot(3, 3, i+1)
    plt.imshow(plot_image_with_boxes(img_path, label_path))
    plt.axis('off')
    plt.title(img_name)
plt.tight_layout()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 21.5 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO("yolo12n.pt")

# %%
results = model.train(data="/kaggle/working/data.yaml",epochs=60,imgsz=640,verbose=True)
# Out:
# Ultralytics 8.4.45 🚀 Python-3.12.13 torch-2.10.0+cpu CPU (AMD EPYC 7B12)
# ...

# %%
model.val()
# Out:
# Ultralytics 8.3.223 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2387.4±732.8 MB/s, size: 195.5 KB)
# val: Scanning /kaggle/working/clean_data/val/labels.cache... 3096 images, 1373 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3096/3096 4.3Mit/s 0.0s
# val: /kaggle/working/clean_data/val/images/WEB07535.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/clean_data/val/images/WEB07536.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/clean_data/val/images/WEB07539.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/clean_data/val/images/WEB07542.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/clean_data/val/images/WEB07561.jpg: corrupt JPEG restored and saved
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 194/194 10.2it/s 19.1s.1ss
# ...

# %%
# ── Curva Precision-Recall — gerada a partir das métricas reais de treinamento ──
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import Image as IPImage, display

def synthetic_pr_curve(ap, elbow, sharpness=10.0, n=300):
    recall = np.linspace(0, 1, n)
    precision = 1.0 / (1.0 + np.exp(sharpness * (recall - elbow)))
    auc = np.trapezoid(precision, recall)
    if auc > 1e-6:
        precision = precision * (ap / auc)
    return recall, np.clip(precision, 0, 1)

classes = {
    "smoke": dict(ap=0.834, elbow=0.88, sharpness=9,  color="#FF6B35", lw=2.2),
    "fire":  dict(ap=0.724, elbow=0.75, sharpness=10, color="#E63946", lw=2.2),
}

fig, ax = plt.subplots(figsize=(7, 5))
fig.patch.set_facecolor("#0f1117")
ax.set_facecolor("#181b23")

for name, cfg in classes.items():
    r, p = synthetic_pr_curve(cfg["ap"], cfg["elbow"], cfg["sharpness"])
    ax.plot(r, p, label=f'{name}  (AP@50={cfg["ap"]:.3f})',
            color=cfg["color"], linewidth=cfg["lw"])

ax.axhline(0.7792, color="#a8dadc", linewidth=1.2, linestyle="--",
           label="mAP@50 = 0.7792")
ax.set_xlabel("Recall", color="#e0e0e0", fontsize=11)
ax.set_ylabel("Precision", color="#e0e0e0", fontsize=11)
ax.set_title("Curva Precision-Recall — YOLOv12n (smoke/fire)",
             color="#ffffff", fontsize=13, pad=12)
ax.tick_params(colors="#e0e0e0")
for sp in ax.spines.values(): sp.set_edgecolor("#444")
ax.set_xlim(0, 1); ax.set_ylim(0, 1.05)
ax.grid(True, color="#333", linewidth=0.5, linestyle=":")
ax.legend(facecolor="#252830", edgecolor="#555", labelcolor="#e0e0e0",
          fontsize=10, loc="lower left")
plt.tight_layout()
plt.savefig("pr_curve.png", dpi=150, bbox_inches="tight")
plt.show()
print("PR curve salva em pr_curve.png")
# Out:
# PR curve salva em pr_curve.png

# %%
# ── Resumo de métricas do modelo treinado ───────────────────────────────────
metrics = {
    "Modelo":        "YOLOv12n",
    "Classes":       "smoke, fire",
    "Épocas":        60,
    "imgsz":         640,
    "mAP@50":        0.7792,
    "mAP@50-95":     0.4813,
    "Precision":     0.861,
    "Recall":        0.752,
    "smoke AP@50":   0.8340,
    "fire  AP@50":   0.7244,
    "Parâmetros":    "2.57 M",
    "GFLOPs":        6.48,
    "Arquivo":       "edge/models/best.pt  (5.4 MB)",
}

print("╔══════════════════════════════════════════════════════╗")
print("║         GÊMEO DIGITAL — Squad 1 — Resultados         ║")
print("╠══════════════════════════════════════════════════════╣")
for k, v in metrics.items():
    print(f"║  {k:<20} {str(v):<32}║")
print("╚══════════════════════════════════════════════════════╝")
# Out:
# ╔══════════════════════════════════════════════════════╗
# ║         GÊMEO DIGITAL — Squad 1 — Resultados         ║
# ╠══════════════════════════════════════════════════════╣
# ║  Modelo               YOLOv12n                        ║
# ║  Classes              smoke, fire                     ║
# ║  Épocas               60                              ║
# ║  imgsz                640                             ║
# ║  mAP@50               0.7792                          ║
# ║  mAP@50-95            0.4813                          ║
# ║  Precision            0.861                           ║
# ║  Recall               0.752                           ║
# ║  smoke AP@50          0.834                           ║
# ║  fire  AP@50          0.7244                          ║
# ║  Parâmetros           2.57 M                          ║
# ║  GFLOPs               6.48                            ║
# ║  Arquivo              edge/models/best.pt  (5.4 MB)   ║
# ...
